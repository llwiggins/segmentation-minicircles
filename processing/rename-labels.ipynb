# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import re
import shutil

# %% [markdown]
# ### masks

# %%
base_dir = Path("../data-preprocessing/")
assert base_dir.exists()
dir_labelled_raw = base_dir / "masks-raw"
assert dir_labelled_raw.exists()
dir_labelled_renamed = base_dir / "masks-renamed"
dir_labelled_renamed.mkdir(exist_ok=True)

file_ext = ".npy"
files = list(dir_labelled_raw.glob(f"*{file_ext}"))
print(f"Found {len(files)} files")

# sort files by the first number in the filename
files.sort(key=lambda x: int(re.search(r"task-(\d+)", x.name).group(1)))
# print sorted filenames
print("Sorted files:")
for file in files:
    print(file.name)

index = 0
for file in files:
    # rename the file to task-<index>.npy
    new_name = f"mask_{index}"
    new_name_with_ext = f"{new_name}{file_ext}"
    new_file = dir_labelled_renamed / new_name_with_ext
    # load the numpy array
    arr = np.load(file)
    # convert to bool for binary mask
    arr = arr.astype(bool)
    print(f"Renaming {file.name} to {new_name}")
    # save the numpy array
    np.save(new_file, arr)

    # save as png too
    # save as png
    png_file = dir_labelled_renamed / f"{new_name}.png"
    plt.imsave(png_file, arr, cmap="viridis")
    index += 1
# Out:
# Found 55 files
# Sorted files:
# task-107-annotation-107-by-2-tag-dna-0.npy
# task-108-annotation-108-by-2-tag-dna-0.npy
# task-109-annotation-109-by-2-tag-dna-0.npy
# task-110-annotation-110-by-2-tag-dna-0.npy
# task-111-annotation-111-by-2-tag-dna-0.npy
# task-112-annotation-112-by-2-tag-dna-0.npy
# task-113-annotation-113-by-2-tag-dna-0.npy
# task-114-annotation-114-by-2-tag-dna-0.npy
# task-115-annotation-115-by-2-tag-dna-0.npy
# task-116-annotation-116-by-2-tag-dna-0.npy
# task-117-annotation-117-by-2-tag-dna-0.npy
# task-118-annotation-118-by-2-tag-dna-0.npy
# task-119-annotation-119-by-2-tag-dna-0.npy
# task-120-annotation-120-by-2-tag-dna-0.npy
# task-121-annotation-121-by-2-tag-dna-0.npy
# task-122-annotation-122-by-2-tag-dna-0.npy
# task-123-annotation-123-by-2-tag-dna-0.npy
# task-124-annotation-124-by-2-tag-dna-0.npy
# task-125-annotation-125-by-2-tag-dna-0.npy
# task-126-annotation-126-by-2-tag-dna-0.npy
# task-127-annotation-127-by-2-tag-dna-0.npy
# task-128-annotation-128-by-2-tag-dna-0.npy
# task-129-annotation-129-by-2-tag-dna-0.npy
# task-130-annotation-130-by-2-tag-dna-0.npy
# task-131-annotation-131-by-2-tag-dna-0.npy
# task-132-annotation-132-by-2-tag-dna-0.npy
# task-133-annotation-133-by-2-tag-dna-0.npy
# task-134-annotation-134-by-2-tag-dna-0.npy
# task-135-annotation-135-by-2-tag-dna-0.npy
# task-136-annotation-136-by-2-tag-dna-0.npy
# task-137-annotation-137-by-2-tag-dna-0.npy
# task-138-annotation-138-by-2-tag-dna-0.npy
# task-139-annotation-139-by-2-tag-dna-0.npy
# task-140-annotation-140-by-2-tag-dna-0.npy
# task-141-annotation-141-by-2-tag-dna-0.npy
# task-142-annotation-142-by-2-tag-dna-0.npy
# task-143-annotation-143-by-2-tag-dna-0.npy
# task-144-annotation-144-by-2-tag-dna-0.npy
# task-145-annotation-145-by-2-tag-dna-0.npy
# task-146-annotation-146-by-2-tag-dna-0.npy
# task-147-annotation-147-by-2-tag-dna-0.npy
# task-148-annotation-148-by-2-tag-dna-0.npy
# task-149-annotation-149-by-2-tag-dna-0.npy
# task-150-annotation-150-by-2-tag-dna-0.npy
# task-151-annotation-151-by-2-tag-dna-0.npy
# task-152-annotation-152-by-2-tag-dna-0.npy
# task-153-annotation-153-by-2-tag-dna-0.npy
# task-154-annotation-154-by-2-tag-dna-0.npy
# task-155-annotation-155-by-2-tag-dna-0.npy
# task-156-annotation-156-by-2-tag-dna-0.npy
# task-157-annotation-157-by-2-tag-dna-0.npy
# task-158-annotation-158-by-2-tag-dna-0.npy
# task-159-annotation-159-by-2-tag-dna-0.npy
# task-160-annotation-160-by-2-tag-dna-0.npy
# task-161-annotation-161-by-2-tag-dna-0.npy
# Renaming task-107-annotation-107-by-2-tag-dna-0.npy to mask_0
# Renaming task-108-annotation-108-by-2-tag-dna-0.npy to mask_1
# Renaming task-109-annotation-109-by-2-tag-dna-0.npy to mask_2
# Renaming task-110-annotation-110-by-2-tag-dna-0.npy to mask_3
# Renaming task-111-annotation-111-by-2-tag-dna-0.npy to mask_4
# Renaming task-112-annotation-112-by-2-tag-dna-0.npy to mask_5
# Renaming task-113-annotation-113-by-2-tag-dna-0.npy to mask_6
# Renaming task-114-annotation-114-by-2-tag-dna-0.npy to mask_7
# Renaming task-115-annotation-115-by-2-tag-dna-0.npy to mask_8
# Renaming task-116-annotation-116-by-2-tag-dna-0.npy to mask_9
# Renaming task-117-annotation-117-by-2-tag-dna-0.npy to mask_10
# Renaming task-118-annotation-118-by-2-tag-dna-0.npy to mask_11
# Renaming task-119-annotation-119-by-2-tag-dna-0.npy to mask_12
# Renaming task-120-annotation-120-by-2-tag-dna-0.npy to mask_13
# Renaming task-121-annotation-121-by-2-tag-dna-0.npy to mask_14
# Renaming task-122-annotation-122-by-2-tag-dna-0.npy to mask_15
# Renaming task-123-annotation-123-by-2-tag-dna-0.npy to mask_16
# Renaming task-124-annotation-124-by-2-tag-dna-0.npy to mask_17
# Renaming task-125-annotation-125-by-2-tag-dna-0.npy to mask_18
# Renaming task-126-annotation-126-by-2-tag-dna-0.npy to mask_19
# Renaming task-127-annotation-127-by-2-tag-dna-0.npy to mask_20
# Renaming task-128-annotation-128-by-2-tag-dna-0.npy to mask_21
# Renaming task-129-annotation-129-by-2-tag-dna-0.npy to mask_22
# Renaming task-130-annotation-130-by-2-tag-dna-0.npy to mask_23
# Renaming task-131-annotation-131-by-2-tag-dna-0.npy to mask_24
# Renaming task-132-annotation-132-by-2-tag-dna-0.npy to mask_25
# Renaming task-133-annotation-133-by-2-tag-dna-0.npy to mask_26
# Renaming task-134-annotation-134-by-2-tag-dna-0.npy to mask_27
# Renaming task-135-annotation-135-by-2-tag-dna-0.npy to mask_28
# Renaming task-136-annotation-136-by-2-tag-dna-0.npy to mask_29
# Renaming task-137-annotation-137-by-2-tag-dna-0.npy to mask_30
# Renaming task-138-annotation-138-by-2-tag-dna-0.npy to mask_31
# Renaming task-139-annotation-139-by-2-tag-dna-0.npy to mask_32
# Renaming task-140-annotation-140-by-2-tag-dna-0.npy to mask_33
# Renaming task-141-annotation-141-by-2-tag-dna-0.npy to mask_34
# Renaming task-142-annotation-142-by-2-tag-dna-0.npy to mask_35
# Renaming task-143-annotation-143-by-2-tag-dna-0.npy to mask_36
# Renaming task-144-annotation-144-by-2-tag-dna-0.npy to mask_37
# Renaming task-145-annotation-145-by-2-tag-dna-0.npy to mask_38
# Renaming task-146-annotation-146-by-2-tag-dna-0.npy to mask_39
# Renaming task-147-annotation-147-by-2-tag-dna-0.npy to mask_40
# Renaming task-148-annotation-148-by-2-tag-dna-0.npy to mask_41
# Renaming task-149-annotation-149-by-2-tag-dna-0.npy to mask_42
# Renaming task-150-annotation-150-by-2-tag-dna-0.npy to mask_43
# Renaming task-151-annotation-151-by-2-tag-dna-0.npy to mask_44
# Renaming task-152-annotation-152-by-2-tag-dna-0.npy to mask_45
# Renaming task-153-annotation-153-by-2-tag-dna-0.npy to mask_46
# Renaming task-154-annotation-154-by-2-tag-dna-0.npy to mask_47
# Renaming task-155-annotation-155-by-2-tag-dna-0.npy to mask_48
# Renaming task-156-annotation-156-by-2-tag-dna-0.npy to mask_49
# Renaming task-157-annotation-157-by-2-tag-dna-0.npy to mask_50
# Renaming task-158-annotation-158-by-2-tag-dna-0.npy to mask_51
# Renaming task-159-annotation-159-by-2-tag-dna-0.npy to mask_52
# Renaming task-160-annotation-160-by-2-tag-dna-0.npy to mask_53
# Renaming task-161-annotation-161-by-2-tag-dna-0.npy to mask_54

# %% [markdown]
# ### images

# %%
# do the same but for images
base_dir = Path("../data-preprocessing/")
dir_images = base_dir / "images"
assert dir_images.exists()
dir_images_renamed = base_dir / "images-renamed"
dir_images_renamed.mkdir(exist_ok=True)
file_ext = ".npy"
files = list(dir_images.glob(f"*{file_ext}"))
print(f"Found {len(files)} files")
# sort files by the first number in the filename
files.sort(key=lambda x: int(re.search(r"image_(\d+)", x.name).group(1)))
# print sorted filenames
print("Sorted files:")
for file in files:
    print(file.name)
index = 0
for file in files:
    # rename the file to task-<index>.npy
    new_name = f"image_{index}"
    new_name_with_ext = f"{new_name}{file_ext}"
    new_file = dir_images_renamed / new_name_with_ext
    print(f"Renaming {file.name} to {new_name}")
    shutil.copy(file, new_file)

    # save as png too
    # load the numpy array
    arr = np.load(file)
    # save as png
    png_file = dir_images_renamed / f"{new_name}.png"
    plt.imsave(png_file, arr, cmap="viridis")
    index += 1
